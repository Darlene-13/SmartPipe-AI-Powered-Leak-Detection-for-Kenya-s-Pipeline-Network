# %% [markdown]
# ## LSTM and CNN With sliding window

# %% [markdown]
# ### LIbrary and Paths Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import shutil
import os
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (LSTM, Dense, Input, Dropout, Conv1D, MaxPooling1D, Flatten)
from tensorflow.keras.callbacks import (EarlyStopping, ModelCheckpoint)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import recall_score, confusion_matrix, classification_report
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras.layers import BatchNormalization

import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import random

WINDOW_SIZE = 10
N_CLASSES = 3
BATCH_SIZE = 128
EPOCHS = 100
LEARNING_RATE = 0.001

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

BASE_PATH = Path.cwd().parent.parent
SCALED_PATH = BASE_PATH / "data" / "model-live" / "scaled"
MODEL_PATH = BASE_PATH / "models"
ASSETS_PATH = BASE_PATH/ "assets"/ "live"
artifacts_path = BASE_PATH/ "artifacts"
artifacts_path.mkdir(parents=True, exist_ok=True)
# Out:
# 2026-05-31 08:56:35.616049: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-31 08:56:35.788561: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-31 08:56:36.449218: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-31 08:56:38.799703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Data Loading

# %%
# Load data that has been scaled.
# Loading the Robust Scaled data and then, switch to Standard Scaled data later for comparison.

# Load scaled data (ROBUST versions)
X_train = pd.read_csv(SCALED_PATH / "X_train_robust_live_data.csv")
X_val   = pd.read_csv(SCALED_PATH / "X_val_robust_live_data.csv")
X_test  = pd.read_csv(SCALED_PATH / "X_test_robust_live_data.csv")

y_train = pd.read_csv(SCALED_PATH / "y_train_live.csv").squeeze()
y_val   = pd.read_csv(SCALED_PATH / "y_val_live.csv").squeeze()
y_test  = pd.read_csv(SCALED_PATH / "y_test_live.csv").squeeze()

train_meta = pd.read_csv(SCALED_PATH / "train_meta.csv")
val_meta   = pd.read_csv(SCALED_PATH / "val_meta.csv")
test_meta  = pd.read_csv(SCALED_PATH / "test_meta.csv")

train_scenario_ids = train_meta["scenario_id"].values
train_timesteps    = train_meta["timestep"].values

val_scenario_ids = val_meta["scenario_id"].values
val_timesteps    = val_meta["timestep"].values

test_scenario_ids = test_meta["scenario_id"].values
test_timesteps    = test_meta["timestep"].values

N_FEATURES = X_train.shape[1]

# Verify shapes
print("DATA SHAPES")
print("-" * 30)
print(f"X_train: {X_train.shape} | y_train: {y_train.shape}")
print(f"X_val  : {X_val.shape}   | y_val  : {y_val.shape}")
print(f"X_test : {X_test.shape}  | y_test : {y_test.shape}")
print(f"Features: {N_FEATURES}")
print(f"Window size: {WINDOW_SIZE}")
print(f"Input shape per sequence: ({WINDOW_SIZE}, {N_FEATURES})")
# Out:
# DATA SHAPES
# ------------------------------
# X_train: (113562, 51) | y_train: (113562,)
# X_val  : (18927, 51)   | y_val  : (18927,)
# X_test : (18927, 51)  | y_test : (18927,)
# Features: 51
# Window size: 10
# Input shape per sequence: (10, 51)

# %% [markdown]
# ### Building Sequence using Scenario Id

# %%
def build_sequences(X, y, window_size):
    """
    Slide a window over a single scenario's timesteps.
    Label = label of the LAST timestep in each window.
    """
    sequences = []
    labels = []

    for i in range(window_size, len(X) + 1):
        window = X[i - window_size : i]
        label  = y.iloc[i - 1]
        sequences.append(window)
        labels.append(label)

    return np.array(sequences), np.array(labels)

def build_sequences_safe(X_df, y_series, scenario_ids, window_size=WINDOW_SIZE):
    """
    Calls build_sequences per scenario so windows never
    span two different scenarios.
    """
    all_X, all_y = [], []

    for scenario in np.unique(scenario_ids):
        mask     = scenario_ids == scenario
        X_sc     = X_df[mask]
        y_sc     = y_series[mask]

        # skip scenarios too short to fill one window
        if len(X_sc) < window_size:
            continue

        Xs, ys = build_sequences(X_sc, y_sc, window_size)
        all_X.append(Xs)
        all_y.append(ys)

    return np.concatenate(all_X), np.concatenate(all_y)

X_train_seq, y_train_seq = build_sequences_safe(
    X_train, y_train, train_scenario_ids)

X_val_seq, y_val_seq = build_sequences_safe(
    X_val, y_val, val_scenario_ids)

X_test_seq, y_test_seq = build_sequences_safe(
    X_test, y_test, test_scenario_ids)

print("SEQUENCE SHAPES")
print("-" * 30)
print(f"X_train_seq : {X_train_seq.shape}")
print(f"X_val_seq   : {X_val_seq.shape}")
print(f"X_test_seq  : {X_test_seq.shape}")
# Out:
# SEQUENCE SHAPES
# ------------------------------
# X_train_seq : (112104, 10, 51)
# X_val_seq   : (18684, 10, 51)
# X_test_seq  : (18684, 10, 51)

# %% [markdown]
# ### One Hot Encoding using to_categorical

# %%
# Keras softmax needs (n, 3)
y_train_cat = to_categorical(y_train_seq, num_classes=N_CLASSES)
y_val_cat   = to_categorical(y_val_seq,   num_classes=N_CLASSES)
y_test_cat  = to_categorical(y_test_seq,  num_classes=N_CLASSES)

print("\nONE-HOT SHAPES")
print("-" * 30)
print(f"y_train_cat : {y_train_cat.shape}")
print(f"y_val_cat   : {y_val_cat.shape}")
print(f"y_test_cat  : {y_test_cat.shape}")
# Out:
# ONE-HOT SHAPES
# ------------------------------
# y_train_cat : (112104, 3)
# y_val_cat   : (18684, 3)
# y_test_cat  : (18684, 3)

# %% [markdown]
# ### Building MLP (Multi layer Perceptron) -> Base Model

# %%
def build_mlp(input_shape,n_classes, learning_rate):
    model = Sequential([
        Input(shape = input_shape),
        Flatten(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(n_classes, activation = 'softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate, clipnorm=1.0),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

mlp_model = build_mlp(
    input_shape=(WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes = N_CLASSES,
    learning_rate=0.0001
)

mlp_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 510)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       130,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 173,955 (679.51 KB)
#  Trainable params: 173,059 (676.01 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ### Build LSTM and CNN models

# %%
def build_lstm(input_shape, n_classes, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        GaussianNoise(0.005),

        LSTM(128,
             return_sequences=True,
             kernel_regularizer=l2(0.0005),
             recurrent_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        LSTM(64,
             return_sequences=False,
             kernel_regularizer=l2(0.0005),
             recurrent_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(n_classes, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

lstm_model = build_lstm(
    input_shape=(WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes=N_CLASSES,
    learning_rate = LEARNING_RATE
)

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gaussian_noise (GaussianNoise)  │ (None, 10, 51)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 10, 128)        │        92,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 10, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 144,515 (564.51 KB)
#  Trainable params: 144,131 (563.01 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
def build_cnn(input_shape, n_classes, learning_rate):

    model = Sequential([
        Conv1D(filters=64, kernel_size=3,
               activation="relu",
               kernel_regularizer=l2(0.0005),
               input_shape=input_shape),

        BatchNormalization(),   # to reduce internal covariance shift
        MaxPooling1D(pool_size=2),
        Dropout(0.3),

        Conv1D(filters= 128, kernel_size=3,
               activation="relu",
               kernel_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        Flatten(),   # flattening to 1D vector
        Dense(64, activation="relu"),
        Dropout(0.2),
        Dense(n_classes, activation="softmax")
    ])

    model.compile(
        optimizer=Adam(learning_rate, clipnorm=1.0),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

cnn_model = build_cnn(
    input_shape = (WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes = N_CLASSES,
    learning_rate = LEARNING_RATE
)

cnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 8, 64)          │         9,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 2, 128)         │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 2, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,971 (203.01 KB)
#  Trainable params: 51,587 (201.51 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ### Model Callbacks

# %%
def get_callbacks(model_name):
    return[
        EarlyStopping(
            monitor = "val_loss",
            patience = 15,
            restore_best_weights = True,
            min_delta = 0.001,
        ),
        ModelCheckpoint(
            filepath= artifacts_path/ f"{model_name}_best_live_model.keras",
            monitor = "val_loss",
            save_best_only = True,
            mode = "min",
            verbose = 1
        )
    ]

# %% [markdown]
# ### Training MLP

# %%
start_time = time.time()
print(start_time)

mlp_history = mlp_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("mlp"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(mlp_history.history['loss'])}")
# Out:
# 1780207080.07623
# Epoch 1/100
# 2026-05-31 08:58:00.244189: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8264 - loss: 0.4472
# Epoch 1: val_loss improved from None to 0.03815, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 1: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9375 - loss: 0.1865 - val_accuracy: 0.9957 - val_loss: 0.0381
# Epoch 2/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9934 - loss: 0.0292
# Epoch 2: val_loss improved from 0.03815 to 0.01580, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 2: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9939 - loss: 0.0255 - val_accuracy: 0.9959 - val_loss: 0.0158
# Epoch 3/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9949 - loss: 0.0182
# Epoch 3: val_loss improved from 0.01580 to 0.01152, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 3: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9951 - loss: 0.0169 - val_accuracy: 0.9960 - val_loss: 0.0115
# Epoch 4/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9958 - loss: 0.0131
# Epoch 4: val_loss improved from 0.01152 to 0.00912, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 4: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9958 - loss: 0.0127 - val_accuracy: 0.9963 - val_loss: 0.0091
# Epoch 5/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9961 - loss: 0.0111
# Epoch 5: val_loss did not improve from 0.00912
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9960 - loss: 0.0111 - val_accuracy: 0.9960 - val_loss: 0.0100
# Epoch 6/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9963 - loss: 0.0098
# Epoch 6: val_loss improved from 0.00912 to 0.00733, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 6: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9962 - loss: 0.0098 - val_accuracy: 0.9974 - val_loss: 0.0073
# Epoch 7/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9967 - loss: 0.0086
# Epoch 7: val_loss improved from 0.00733 to 0.00546, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 7: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9964 - loss: 0.0088 - val_accuracy: 0.9975 - val_loss: 0.0055
# Epoch 8/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9967 - loss: 0.0076
# Epoch 8: val_loss did not improve from 0.00546
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9968 - loss: 0.0075 - val_accuracy: 0.9976 - val_loss: 0.0057
# Epoch 9/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9968 - loss: 0.0078
# Epoch 9: val_loss did not improve from 0.00546
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9968 - loss: 0.0077 - val_accuracy: 0.9974 - val_loss: 0.0057
# Epoch 10/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0065
# Epoch 10: val_loss did not improve from 0.00546
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9972 - loss: 0.0062 - val_accuracy: 0.9980 - val_loss: 0.0056
# Epoch 11/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9973 - loss: 0.0063
# Epoch 11: val_loss improved from 0.00546 to 0.00426, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 11: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9975 - loss: 0.0059 - val_accuracy: 0.9980 - val_loss: 0.0043
# Epoch 12/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9975 - loss: 0.0055
# Epoch 12: val_loss improved from 0.00426 to 0.00380, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 12: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9974 - loss: 0.0057 - val_accuracy: 0.9979 - val_loss: 0.0038
# Epoch 13/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9974 - loss: 0.0060
# Epoch 13: val_loss did not improve from 0.00380
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9975 - loss: 0.0056 - val_accuracy: 0.9981 - val_loss: 0.0041
# Epoch 14/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9977 - loss: 0.0050
# Epoch 14: val_loss improved from 0.00380 to 0.00372, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 14: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9977 - loss: 0.0051 - val_accuracy: 0.9984 - val_loss: 0.0037
# Epoch 15/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0048
# Epoch 15: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9977 - loss: 0.0050 - val_accuracy: 0.9980 - val_loss: 0.0038
# Epoch 16/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0041
# Epoch 16: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9978 - loss: 0.0043 - val_accuracy: 0.9980 - val_loss: 0.0048
# Epoch 17/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0043
# Epoch 17: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9978 - loss: 0.0048 - val_accuracy: 0.9984 - val_loss: 0.0042
# Epoch 18/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9978 - loss: 0.0050
# Epoch 18: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9980 - loss: 0.0044 - val_accuracy: 0.9983 - val_loss: 0.0039
# Epoch 19/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9984 - loss: 0.0040
# Epoch 19: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9982 - loss: 0.0041 - val_accuracy: 0.9980 - val_loss: 0.0054
# Epoch 20/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0039
# Epoch 20: val_loss did not improve from 0.00372
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.9981 - val_loss: 0.0058
# Epoch 21/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9983 - loss: 0.0041
# Epoch 21: val_loss improved from 0.00372 to 0.00292, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 21: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.9985 - val_loss: 0.0029
# Epoch 22/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9983 - loss: 0.0038
# Epoch 22: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.9986 - val_loss: 0.0043
# Epoch 23/100
# 867/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0031
# Epoch 23: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9986 - loss: 0.0034 - val_accuracy: 0.9982 - val_loss: 0.0056
# Epoch 24/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0032
# Epoch 24: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9986 - loss: 0.0034 - val_accuracy: 0.9988 - val_loss: 0.0043
# Epoch 25/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0026
# Epoch 25: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9988 - loss: 0.0028 - val_accuracy: 0.9989 - val_loss: 0.0050
# Epoch 26/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0030
# Epoch 26: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9989 - loss: 0.0028 - val_accuracy: 0.9989 - val_loss: 0.0046
# Epoch 27/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0024
# Epoch 27: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9990 - loss: 0.0029 - val_accuracy: 0.9989 - val_loss: 0.0039
# Epoch 28/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0024
# Epoch 28: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9990 - loss: 0.0024 - val_accuracy: 0.9989 - val_loss: 0.0048
# Epoch 29/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0027
# Epoch 29: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9990 - loss: 0.0025 - val_accuracy: 0.9990 - val_loss: 0.0050
# Epoch 30/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9994 - loss: 0.0020
# Epoch 30: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9988 - val_loss: 0.0058
# Epoch 31/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9993 - loss: 0.0020
# Epoch 31: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9994 - val_loss: 0.0049
# Epoch 32/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0027
# Epoch 32: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9992 - loss: 0.0023 - val_accuracy: 0.9986 - val_loss: 0.0065
# Epoch 33/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0016
# Epoch 33: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9986 - val_loss: 0.0071
# Epoch 34/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0017
# Epoch 34: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9992 - loss: 0.0021 - val_accuracy: 0.9991 - val_loss: 0.0056
# Epoch 35/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9994 - loss: 0.0018
# Epoch 35: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9993 - val_loss: 0.0060
# Epoch 36/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9996 - loss: 0.0012
# Epoch 36: val_loss did not improve from 0.00292
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9993 - val_loss: 0.0054
#
# Training time : 228.7s  (3.8 mins)
# Stopped at epoch: 36

# %% [markdown]
# ### Training LSTM

# %%
start_time = time.time()
print(start_time)

lstm_history = lstm_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("lstm"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(lstm_history.history['loss'])}")
# Out:
# 1780207309.0076067
# Epoch 1/100
# 2026-05-31 09:01:49.951709: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9685 - loss: 0.2361
# Epoch 1: val_loss improved from None to 0.04881, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 1: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 47s 44ms/step - accuracy: 0.9904 - loss: 0.1273 - val_accuracy: 0.9967 - val_loss: 0.0488
# Epoch 2/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9983 - loss: 0.0396
# Epoch 2: val_loss did not improve from 0.04881
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 33s 38ms/step - accuracy: 0.9981 - loss: 0.0351 - val_accuracy: 0.9911 - val_loss: 0.0735
# Epoch 3/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9990 - loss: 0.0249
# Epoch 3: val_loss improved from 0.04881 to 0.01455, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 3: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 48s 45ms/step - accuracy: 0.9991 - loss: 0.0218 - val_accuracy: 0.9996 - val_loss: 0.0145
# Epoch 4/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9988 - loss: 0.0195
# Epoch 4: val_loss did not improve from 0.01455
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 36s 39ms/step - accuracy: 0.9990 - loss: 0.0180 - val_accuracy: 0.9988 - val_loss: 0.0160
# Epoch 5/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9986 - loss: 0.0165
# Epoch 5: val_loss improved from 0.01455 to 0.01094, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 5: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 34s 39ms/step - accuracy: 0.9993 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 6/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9996 - loss: 0.0107
# Epoch 6: val_loss improved from 0.01094 to 0.00971, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 6: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9991 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 7/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9997 - loss: 0.0094
# Epoch 7: val_loss improved from 0.00971 to 0.00783, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 7: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 26s 30ms/step - accuracy: 0.9995 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 8/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9993 - loss: 0.0155
# Epoch 8: val_loss improved from 0.00783 to 0.00595, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 8: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9996 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 9/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9993 - loss: 0.0093
# Epoch 9: val_loss did not improve from 0.00595
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9989 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 10/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9995 - loss: 0.0106
# Epoch 10: val_loss did not improve from 0.00595
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 26s 30ms/step - accuracy: 0.9996 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 11/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9999 - loss: 0.0055
# Epoch 11: val_loss improved from 0.00595 to 0.00442, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 11: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 33s 38ms/step - accuracy: 0.9999 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 12/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9970 - loss: 0.0162
# Epoch 12: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 35s 40ms/step - accuracy: 0.9983 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 13/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9991 - loss: 0.0118
# Epoch 13: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 37s 42ms/step - accuracy: 0.9992 - loss: 0.0106 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 14/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9997 - loss: 0.0102
# Epoch 14: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 34s 34ms/step - accuracy: 0.9998 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 15/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9997 - loss: 0.0078
# Epoch 15: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 27s 31ms/step - accuracy: 0.9996 - loss: 0.0079 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 16/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9965 - loss: 0.0146
# Epoch 16: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9943 - loss: 0.0232 - val_accuracy: 0.9986 - val_loss: 0.0214
# Epoch 17/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9997 - loss: 0.0111
# Epoch 17: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.9998 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 18/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9990 - loss: 0.0109
# Epoch 18: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.9991 - loss: 0.0098 - val_accuracy: 0.9912 - val_loss: 0.0289
# Epoch 19/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9945 - loss: 0.0310
# Epoch 19: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.9959 - loss: 0.0279 - val_accuracy: 0.9997 - val_loss: 0.0120
# Epoch 20/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9981 - loss: 0.0167
# Epoch 20: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9983 - loss: 0.0155 - val_accuracy: 0.9997 - val_loss: 0.0081
# Epoch 21/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9992 - loss: 0.0103
# Epoch 21: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9990 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 22/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9997 - loss: 0.0080
# Epoch 22: val_loss did not improve from 0.00442
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9994 - loss: 0.0094 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 23/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 23: val_loss improved from 0.00442 to 0.00319, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 23: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step - accuracy: 0.9999 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 24/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9974 - loss: 0.0126
# Epoch 24: val_loss did not improve from 0.00319
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.9966 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 25/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0046
# Epoch 25: val_loss did not improve from 0.00319
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.9999 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 26/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9986 - loss: 0.0150
# Epoch 26: val_loss did not improve from 0.00319
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 83s 95ms/step - accuracy: 0.9986 - loss: 0.0150 - val_accuracy: 0.9995 - val_loss: 0.0108
# Epoch 27/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9993 - loss: 0.0097
# Epoch 27: val_loss did not improve from 0.00319
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 36s 41ms/step - accuracy: 0.9992 - loss: 0.0092 - val_accuracy: 0.9984 - val_loss: 0.0102
# Epoch 28/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9994 - loss: 0.0075
# Epoch 28: val_loss did not improve from 0.00319
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9993 - loss: 0.0088 - val_accuracy: 0.9995 - val_loss: 0.0065
# Epoch 29/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9995 - loss: 0.0061
# Epoch 29: val_loss improved from 0.00319 to 0.00279, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 29: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 33s 38ms/step - accuracy: 0.9997 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 30/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9983 - loss: 0.0079
# Epoch 30: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9945 - loss: 0.0179 - val_accuracy: 0.9904 - val_loss: 0.0268
# Epoch 31/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9978 - loss: 0.0131
# Epoch 31: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 26s 30ms/step - accuracy: 0.9991 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 32/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9994 - loss: 0.0069
# Epoch 32: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 35ms/step - accuracy: 0.9992 - loss: 0.0085 - val_accuracy: 0.9999 - val_loss: 0.0061
# Epoch 33/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9987 - loss: 0.0099
# Epoch 33: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 37s 42ms/step - accuracy: 0.9984 - loss: 0.0112 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 34/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9997 - loss: 0.0061
# Epoch 34: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 25s 28ms/step - accuracy: 0.9996 - loss: 0.0069 - val_accuracy: 0.9999 - val_loss: 0.0052
# Epoch 35/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9996 - loss: 0.0068
# Epoch 35: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 28s 32ms/step - accuracy: 0.9998 - loss: 0.0055 - val_accuracy: 0.9999 - val_loss: 0.0046
# Epoch 36/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9996 - loss: 0.0068
# Epoch 36: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9996 - loss: 0.0067 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 37/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9995 - loss: 0.0081
# Epoch 37: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 29s 33ms/step - accuracy: 0.9997 - loss: 0.0070 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 38/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9999 - loss: 0.0033
# Epoch 38: val_loss did not improve from 0.00279
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 30s 34ms/step - accuracy: 0.9995 - loss: 0.0062 - val_accuracy: 0.9995 - val_loss: 0.0101
#
# Training time : 1235.5s  (20.6 mins)
# Stopped at epoch: 38

# %% [markdown]
# ### Training CNN

# %%
start_time = time.time()
print(start_time)

cnn_history = cnn_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("cnn"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(cnn_history.history['loss'])}")
# Out:
# 1780208544.6303022
# Epoch 1/100
# 2026-05-31 09:22:24.929442: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9377 - loss: 0.2136
# Epoch 1: val_loss improved from None to 0.04831, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 1: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - accuracy: 0.9805 - loss: 0.1036 - val_accuracy: 0.9944 - val_loss: 0.0483
# Epoch 2/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - loss: 0.0434
# Epoch 2: val_loss improved from 0.04831 to 0.02901, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 2: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9961 - loss: 0.0362 - val_accuracy: 0.9966 - val_loss: 0.0290
# Epoch 3/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9970 - loss: 0.0261
# Epoch 3: val_loss improved from 0.02901 to 0.01698, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 3: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9972 - loss: 0.0240 - val_accuracy: 0.9985 - val_loss: 0.0170
# Epoch 4/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9971 - loss: 0.0231
# Epoch 4: val_loss improved from 0.01698 to 0.01111, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 4: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9973 - loss: 0.0215 - val_accuracy: 0.9993 - val_loss: 0.0111
# Epoch 5/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9982 - loss: 0.0149
# Epoch 5: val_loss improved from 0.01111 to 0.01060, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 5: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9982 - loss: 0.0149 - val_accuracy: 0.9987 - val_loss: 0.0106
# Epoch 6/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.0109
# Epoch 6: val_loss did not improve from 0.01060
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9987 - loss: 0.0114 - val_accuracy: 0.9968 - val_loss: 0.0139
# Epoch 7/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0124
# Epoch 7: val_loss did not improve from 0.01060
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9983 - loss: 0.0126 - val_accuracy: 0.9991 - val_loss: 0.0186
# Epoch 8/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9991 - loss: 0.0100
# Epoch 8: val_loss did not improve from 0.01060
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9988 - loss: 0.0107 - val_accuracy: 0.9979 - val_loss: 0.0305
# Epoch 9/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9972 - loss: 0.0175
# Epoch 9: val_loss improved from 0.01060 to 0.00784, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 9: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9978 - loss: 0.0152 - val_accuracy: 0.9993 - val_loss: 0.0078
# Epoch 10/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0102
# Epoch 10: val_loss improved from 0.00784 to 0.00711, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 10: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9988 - loss: 0.0105 - val_accuracy: 0.9993 - val_loss: 0.0071
# Epoch 11/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9984 - loss: 0.0120
# Epoch 11: val_loss improved from 0.00711 to 0.00646, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 11: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9985 - loss: 0.0115 - val_accuracy: 0.9997 - val_loss: 0.0065
# Epoch 12/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9987 - loss: 0.0101
# Epoch 12: val_loss did not improve from 0.00646
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9980 - loss: 0.0126 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 13/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9986 - loss: 0.0110
# Epoch 13: val_loss did not improve from 0.00646
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.9985 - loss: 0.0114 - val_accuracy: 0.9973 - val_loss: 0.0316
# Epoch 14/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9984 - loss: 0.0126
# Epoch 14: val_loss did not improve from 0.00646
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 12s 13ms/step - accuracy: 0.9986 - loss: 0.0127 - val_accuracy: 0.9993 - val_loss: 0.0075
# Epoch 15/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9986 - loss: 0.0113
# Epoch 15: val_loss did not improve from 0.00646
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9984 - loss: 0.0117 - val_accuracy: 0.9936 - val_loss: 0.0251
# Epoch 16/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0106
# Epoch 16: val_loss improved from 0.00646 to 0.00593, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 16: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9987 - loss: 0.0105 - val_accuracy: 0.9998 - val_loss: 0.0059
# Epoch 17/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9993 - loss: 0.0080
# Epoch 17: val_loss improved from 0.00593 to 0.00591, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 17: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9990 - loss: 0.0089 - val_accuracy: 0.9996 - val_loss: 0.0059
# Epoch 18/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0092
# Epoch 18: val_loss did not improve from 0.00591
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9986 - loss: 0.0102 - val_accuracy: 0.9991 - val_loss: 0.0087
# Epoch 19/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.0110
# Epoch 19: val_loss did not improve from 0.00591
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9985 - loss: 0.0114 - val_accuracy: 0.9996 - val_loss: 0.0067
# Epoch 20/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0090
# Epoch 20: val_loss did not improve from 0.00591
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9984 - loss: 0.0113 - val_accuracy: 0.9944 - val_loss: 0.0202
# Epoch 21/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9987 - loss: 0.0108
# Epoch 21: val_loss did not improve from 0.00591
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9987 - loss: 0.0103 - val_accuracy: 0.9991 - val_loss: 0.0088
# Epoch 22/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0093
# Epoch 22: val_loss did not improve from 0.00591
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9985 - loss: 0.0105 - val_accuracy: 0.9999 - val_loss: 0.0067
# Epoch 23/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0098
# Epoch 23: val_loss improved from 0.00591 to 0.00506, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 23: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9988 - loss: 0.0097 - val_accuracy: 0.9999 - val_loss: 0.0051
# Epoch 24/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9982 - loss: 0.0113
# Epoch 24: val_loss improved from 0.00506 to 0.00467, saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 24: finished saving model to /home/local-host/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0096 - val_accuracy: 0.9997 - val_loss: 0.0047
# Epoch 25/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0092
# Epoch 25: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0094 - val_accuracy: 0.9932 - val_loss: 0.0333
# Epoch 26/100
# 872/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0098
# Epoch 26: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9986 - loss: 0.0111 - val_accuracy: 0.9986 - val_loss: 0.0101
# Epoch 27/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0107
# Epoch 27: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9988 - loss: 0.0103 - val_accuracy: 0.9997 - val_loss: 0.0055
# Epoch 28/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0090
# Epoch 28: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9988 - loss: 0.0093 - val_accuracy: 0.9936 - val_loss: 0.0188
# Epoch 29/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9979 - loss: 0.0121
# Epoch 29: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9980 - loss: 0.0125 - val_accuracy: 0.9987 - val_loss: 0.0098
# Epoch 30/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.0100
# Epoch 30: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9987 - loss: 0.0102 - val_accuracy: 0.9995 - val_loss: 0.0064
# Epoch 31/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9990 - loss: 0.0091
# Epoch 31: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9987 - loss: 0.0107 - val_accuracy: 0.9999 - val_loss: 0.0060
# Epoch 32/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9989 - loss: 0.0087
# Epoch 32: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9986 - loss: 0.0100 - val_accuracy: 0.9992 - val_loss: 0.0132
# Epoch 33/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9990 - loss: 0.0095
# Epoch 33: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9988 - loss: 0.0099 - val_accuracy: 0.9960 - val_loss: 0.0168
# Epoch 34/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0087
# Epoch 34: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9985 - loss: 0.0105 - val_accuracy: 0.9978 - val_loss: 0.0095
# Epoch 35/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9988 - loss: 0.0094
# Epoch 35: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9988 - loss: 0.0097 - val_accuracy: 0.9986 - val_loss: 0.0090
# Epoch 36/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9984 - loss: 0.0108
# Epoch 36: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.9985 - loss: 0.0110 - val_accuracy: 0.9961 - val_loss: 0.0131
# Epoch 37/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9992 - loss: 0.0074
# Epoch 37: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9990 - loss: 0.0081 - val_accuracy: 0.9890 - val_loss: 0.0898
# Epoch 38/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.0137
# Epoch 38: val_loss did not improve from 0.00467
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9984 - loss: 0.0111 - val_accuracy: 0.9959 - val_loss: 0.0176
#
# Training time : 287.2s  (4.8 mins)
# Stopped at epoch: 38

# %% [markdown]
# ### Plot Training accuracy

# %%
ASSETS_PATH.mkdir(parents=True, exist_ok=True)

def plot_history(history, model_name):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f"{model_name} Training History live data", fontsize=14, fontweight="bold")

    epochs_range = range(1, len(history.history["loss"]) + 1)

    # best epoch indices
    best_epoch_idx     = int(np.argmin(history.history["val_loss"]))
    best_epoch         = best_epoch_idx + 1
    best_val_loss      = history.history["val_loss"][best_epoch_idx]

    best_val_acc_idx   = int(np.argmax(history.history["val_accuracy"]))
    best_val_acc_epoch = best_val_acc_idx + 1
    best_val_acc       = history.history["val_accuracy"][best_val_acc_idx]

    # gap at best epoch — not final epoch
    gap = (history.history['accuracy'][best_epoch_idx] -
           history.history['val_accuracy'][best_epoch_idx])

    # ── Subplot 1: Loss
    ax1.plot(epochs_range, history.history["loss"],
             label="Train Loss", color="#60a5fa", linewidth=2)
    ax1.plot(epochs_range, history.history["val_loss"],
             label="Val Loss",   color="#fb923c", linewidth=2)

    ax1.axvline(best_epoch, color="#4ade80", linestyle="--", alpha=0.7,
                label=f"Best epoch ({best_epoch})")
    ax1.scatter([best_epoch], [best_val_loss], color="#4ade80", s=80, zorder=5)

    ax1.set_title("Training vs Validation Loss Live data")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(alpha=0.3)

    #  Subplot 2: Accuracy
    ax2.plot(epochs_range, history.history["accuracy"],
             label="Train Accuracy", color="#4ade80", linewidth=2)
    ax2.plot(epochs_range, history.history["val_accuracy"],
             label="Val Accuracy",   color="#f472b6", linewidth=2)

    ax2.axvline(best_val_acc_epoch, color="#fbbf24", linestyle="--", alpha=0.7,
                label=f"Best val_acc epoch ({best_val_acc_epoch})")
    ax2.scatter([best_val_acc_epoch], [best_val_acc],
                color="#fbbf24", s=80, zorder=5)

    ax2.set_title("Training vs Validation Accuracy")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Accuracy")
    ax2.set_ylim([0, 1.05])
    ax2.legend()
    ax2.grid(alpha=0.3)

    plt.tight_layout()
    save_path = ASSETS_PATH / f"{model_name.lower()}_training_history.png"
    plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()

    # Diagnosis at best epoch
    print(f"\n{model_name} TRAINING DIAGNOSIS")
    print("-" * 40)
    print(f"Total epochs run      : {len(history.history['loss'])}")
    print(f"Best val_loss         : {best_val_loss:.4f}  (epoch {best_epoch})")
    print(f"Best val_accuracy     : {best_val_acc:.4f}  (epoch {best_val_acc_epoch})")
    print(f"Train accuracy @ best : {history.history['accuracy'][best_epoch_idx]:.4f}")
    print(f"Val accuracy   @ best : {history.history['val_accuracy'][best_epoch_idx]:.4f}")
    print(f"Train/Val gap         : {gap:.4f}  {'OVERFIT' if gap > 0.05 else 'OK'}")


# ── Call for all three models
plot_history(lstm_history, "LSTM")
plot_history(cnn_history,  "CNN")
plot_history(mlp_history,  "MLP")
# Out:
# LSTM TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 38
# Best val_loss         : 0.0028  (epoch 29)
# Best val_accuracy     : 1.0000  (epoch 5)
# Train accuracy @ best : 0.9997
# Val accuracy   @ best : 1.0000
# Train/Val gap         : -0.0003  OK
# CNN TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 38
# Best val_loss         : 0.0047  (epoch 24)
# Best val_accuracy     : 1.0000  (epoch 12)
# Train accuracy @ best : 0.9987
# Val accuracy   @ best : 0.9997
# Train/Val gap         : -0.0010  OK
# MLP TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 36
# Best val_loss         : 0.0029  (epoch 21)
# Best val_accuracy     : 0.9994  (epoch 31)
# Train accuracy @ best : 0.9984
# Val accuracy   @ best : 0.9985
# Train/Val gap         : -0.0001  OK

# %% [markdown]
# ### Evaluate on Validation set

# %%
def evaluate_model(model, model_name, X_val_seq, y_val_cat):
    """
    - Classification report
    - Confusion matrix (counts + percentages)
    - Leak recall extraction
    - Saves confusion matrix to assets folder
    """
    CLASS_NAMES = ["Normal", "Leak", "Blockage"]

    # Predict
    y_pred_prob = model.predict(X_val_seq, verbose=0)
    y_pred      = np.argmax(y_pred_prob, axis=1)
    y_true      = np.argmax(y_val_cat,   axis=1)

    # Classification Report
    print("=" * 50)
    print(f"{model_name} — LIVE DATA VALIDATION SET RESULTS")
    print("=" * 50)
    print(classification_report(
        y_true, y_pred,
        target_names=CLASS_NAMES,
        digits=4
    ))

    # Leak Recall
    leak_recall = recall_score(y_true, y_pred, labels=[1], average=None)[0]

    # Confusion Matrix
    cm     = confusion_matrix(y_true, y_pred)
    cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                ax=axes[0], linewidths=0.5)
    axes[0].set_title("Confusion Matrix — Counts")
    axes[0].set_ylabel("True Label")
    axes[0].set_xlabel("Predicted Label")

    sns.heatmap(cm_pct, annot=True, fmt=".1f", cmap="RdYlGn",
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
    axes[1].set_title("Confusion Matrix — % per True Class")
    axes[1].set_ylabel("True Label")
    axes[1].set_xlabel("Predicted Label")

    plt.suptitle(f"{model_name} — Validation Set Confusion Matrix",
                 fontweight="bold")
    plt.tight_layout()

    save_path = ASSETS_PATH / f"{model_name.lower()}_val_confusion.png"
    plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()

    return leak_recall


# Run for all three models
leak_recall_lstm = evaluate_model(lstm_model, "LSTM", X_val_seq, y_val_cat)
leak_recall_cnn  = evaluate_model(cnn_model,  "CNN",  X_val_seq, y_val_cat)
leak_recall_mlp  = evaluate_model(mlp_model,  "MLP",  X_val_seq, y_val_cat)
# Out:
# ==================================================
# LSTM — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    1.0000    1.0000      6228
#         Leak     1.0000    1.0000    1.0000      6228
#     Blockage     1.0000    1.0000    1.0000      6228
#
#     accuracy                         1.0000     18684
#    macro avg     1.0000    1.0000    1.0000     18684
# weighted avg     1.0000    1.0000    1.0000     18684
# ==================================================
# CNN — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    1.0000    1.0000      6228
#         Leak     0.9998    1.0000    0.9999      6228
#     Blockage     1.0000    0.9998    0.9999      6228
#
#     accuracy                         0.9999     18684
#    macro avg     0.9999    0.9999    0.9999     18684
# weighted avg     0.9999    0.9999    0.9999     18684
# ==================================================
# MLP — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     0.9963    1.0000    0.9982      6228
#         Leak     0.9992    0.9963    0.9977      6228
#     Blockage     1.0000    0.9992    0.9996      6228
#
#     accuracy                         0.9985     18684
#    macro avg     0.9985    0.9985    0.9985     18684
# weighted avg     0.9985    0.9985    0.9985     18684

# %%
# Load best checkpoint
best_model = load_model(artifacts_path/ "lstm_best_live_model.keras")
print(" Loaded best checkpoint: lstm_best.keras")

# Predict on test set
y_pred_prob_test = best_model.predict(X_test_seq, verbose=0)
y_pred_test      = np.argmax(y_pred_prob_test, axis=1)
y_true_test      = np.argmax(y_test_cat, axis=1)

# Final Classification Report
print("\n" + "=" * 50)
print("LSTM — FINAL TEST SET RESULTS")
print("=" * 50)
print(classification_report(
    y_true_test, y_pred_test,
    target_names=["Normal", "Leak", "Blockage"],
    digits=4
))

# Final Confusion Matrix
cm_test     = confusion_matrix(y_true_test, y_pred_test)
cm_test_pct = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[0], linewidths=0.5)
axes[0].set_title("Test Confusion Matrix — Counts")
axes[0].set_ylabel("True Label")
axes[0].set_xlabel("Predicted Label")

sns.heatmap(cm_test_pct, annot=True, fmt=".1f", cmap="RdYlGn",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
axes[1].set_title("Test Confusion Matrix — % per True Class")
axes[1].set_ylabel("True Label")
axes[1].set_xlabel("Predicted Label")

plt.suptitle("LSTM — Final Test Set Evaluation", fontweight="bold")
plt.tight_layout()
save_path = ASSETS_PATH /"lstm_test_confusion.png"
plt.savefig(save_path, dpi=150, bbox_inches="tight")
plt.show()
# Out:
#  Loaded best checkpoint: lstm_best.keras
#
# ==================================================
# LSTM — FINAL TEST SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    1.0000    1.0000      6228
#         Leak     1.0000    1.0000    1.0000      6228
#     Blockage     1.0000    1.0000    1.0000      6228
#
#     accuracy                         1.0000     18684
#    macro avg     1.0000    1.0000    1.0000     18684
# weighted avg     1.0000    1.0000    1.0000     18684

# %%
# Load best checkpoint
best_model = load_model(artifacts_path/ "cnn_best_live_model.keras")
print(" Loaded best checkpoint: cnn_best.keras")

# Predict on test set
y_pred_prob_test = best_model.predict(X_test_seq, verbose=0)
y_pred_test      = np.argmax(y_pred_prob_test, axis=1)
y_true_test      = np.argmax(y_test_cat, axis=1)

# Final Classification Report
print("\n" + "=" * 50)
print("CNN — FINAL TEST SET RESULTS")
print("=" * 50)
print(classification_report(
    y_true_test, y_pred_test,
    target_names=["Normal", "Leak", "Blockage"],
    digits=4
))

# Final Confusion Matrix
cm_test     = confusion_matrix(y_true_test, y_pred_test)
cm_test_pct = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[0], linewidths=0.5)
axes[0].set_title("Test Confusion Matrix — Counts")
axes[0].set_ylabel("True Label")
axes[0].set_xlabel("Predicted Label")

sns.heatmap(cm_test_pct, annot=True, fmt=".1f", cmap="RdYlGn",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
axes[1].set_title("Test Confusion Matrix — % per True Class")
axes[1].set_ylabel("True Label")
axes[1].set_xlabel("Predicted Label")

plt.suptitle("CNN — Final Test Set Evaluation", fontweight="bold")
plt.tight_layout()
save_path = ASSETS_PATH /"cnn_test_confusion.png"
plt.savefig(save_path, dpi=150, bbox_inches="tight")
plt.show()
# Out:
#  Loaded best checkpoint: cnn_best.keras
#
# ==================================================
# CNN — FINAL TEST SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.9998    0.9999      6228
#         Leak     0.9998    0.9989    0.9994      6228
#     Blockage     0.9989    1.0000    0.9994      6228
#
#     accuracy                         0.9996     18684
#    macro avg     0.9996    0.9996    0.9996     18684
# weighted avg     0.9996    0.9996    0.9996     18684
