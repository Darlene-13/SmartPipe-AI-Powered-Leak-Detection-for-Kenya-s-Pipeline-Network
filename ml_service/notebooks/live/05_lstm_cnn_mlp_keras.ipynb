# %% [markdown]
# ## LSTM and CNN With sliding window

# %% [markdown]
# ### LIbrary and Paths Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import time
import shutil
import os
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (LSTM, Dense, Input, Dropout, Conv1D, MaxPooling1D, Flatten)
from tensorflow.keras.callbacks import (EarlyStopping, ModelCheckpoint)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import recall_score, confusion_matrix, classification_report
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras.layers import BatchNormalization

import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import random

WINDOW_SIZE = 10
N_CLASSES = 3
BATCH_SIZE = 128
EPOCHS = 100
LEARNING_RATE = 0.001

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

BASE_PATH = Path.cwd().parent.parent
SCALED_PATH = BASE_PATH / "data" / "model-live" / "scaled"
MODEL_PATH = BASE_PATH / "models"
ASSETS_PATH = BASE_PATH/ "assets"/ "live"
artifacts_path = BASE_PATH/ "artifacts"
artifacts_path.mkdir(parents=True, exist_ok=True)
# Out:
# 2026-06-04 21:44:48.918310: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-06-04 21:44:49.163599: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-06-04 21:44:49.344492: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780598689.598690   11449 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780598689.650659   11449 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-04 21:44:50.077289: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Data Loading

# %%
# Load data that has been scaled.
# Loading the Robust Scaled data and then, switch to Standard Scaled data later for comparison.

# Load scaled data (ROBUST versions)
X_train = pd.read_csv(SCALED_PATH / "X_train_robust_live_data.csv")
X_val   = pd.read_csv(SCALED_PATH / "X_val_robust_live_data.csv")
X_test  = pd.read_csv(SCALED_PATH / "X_test_robust_live_data.csv")

y_train = pd.read_csv(SCALED_PATH / "y_train_live.csv").squeeze()
y_val   = pd.read_csv(SCALED_PATH / "y_val_live.csv").squeeze()
y_test  = pd.read_csv(SCALED_PATH / "y_test_live.csv").squeeze()

train_meta = pd.read_csv(SCALED_PATH / "train_meta.csv")
val_meta   = pd.read_csv(SCALED_PATH / "val_meta.csv")
test_meta  = pd.read_csv(SCALED_PATH / "test_meta.csv")

train_scenario_ids = train_meta["scenario_id"].values
train_timesteps    = train_meta["timestep"].values

val_scenario_ids = val_meta["scenario_id"].values
val_timesteps    = val_meta["timestep"].values

test_scenario_ids = test_meta["scenario_id"].values
test_timesteps    = test_meta["timestep"].values

N_FEATURES = X_train.shape[1]

# Verify shapes
print("DATA SHAPES")
print("-" * 30)
print(f"X_train: {X_train.shape} | y_train: {y_train.shape}")
print(f"X_val  : {X_val.shape}   | y_val  : {y_val.shape}")
print(f"X_test : {X_test.shape}  | y_test : {y_test.shape}")
print(f"Features: {N_FEATURES}")
print(f"Window size: {WINDOW_SIZE}")
print(f"Input shape per sequence: ({WINDOW_SIZE}, {N_FEATURES})")
# Out:
# DATA SHAPES
# ------------------------------
# X_train: (113562, 51) | y_train: (113562,)
# X_val  : (18927, 51)   | y_val  : (18927,)
# X_test : (18927, 51)  | y_test : (18927,)
# Features: 51
# Window size: 10
# Input shape per sequence: (10, 51)

# %% [markdown]
# ### Building Sequence using Scenario Id

# %%
def build_sequences(X, y, window_size):
    """
    Slide a window over a single scenario's timesteps.
    Label = label of the LAST timestep in each window.
    """
    sequences = []
    labels = []

    for i in range(window_size, len(X) + 1):
        window = X[i - window_size : i]
        label  = y.iloc[i - 1]
        sequences.append(window)
        labels.append(label)

    return np.array(sequences), np.array(labels)

def build_sequences_safe(X_df, y_series, scenario_ids, window_size=WINDOW_SIZE):
    """
    Calls build_sequences per scenario so windows never
    span two different scenarios.
    """
    all_X, all_y = [], []

    for scenario in np.unique(scenario_ids):
        mask     = scenario_ids == scenario
        X_sc     = X_df[mask]
        y_sc     = y_series[mask]

        # skip scenarios too short to fill one window
        if len(X_sc) < window_size:
            continue

        Xs, ys = build_sequences(X_sc, y_sc, window_size)
        all_X.append(Xs)
        all_y.append(ys)

    return np.concatenate(all_X), np.concatenate(all_y)

X_train_seq, y_train_seq = build_sequences_safe(
    X_train, y_train, train_scenario_ids)

X_val_seq, y_val_seq = build_sequences_safe(
    X_val, y_val, val_scenario_ids)

X_test_seq, y_test_seq = build_sequences_safe(
    X_test, y_test, test_scenario_ids)

print("SEQUENCE SHAPES")
print("-" * 30)
print(f"X_train_seq : {X_train_seq.shape}")
print(f"X_val_seq   : {X_val_seq.shape}")
print(f"X_test_seq  : {X_test_seq.shape}")
# Out:
# SEQUENCE SHAPES
# ------------------------------
# X_train_seq : (112104, 10, 51)
# X_val_seq   : (18684, 10, 51)
# X_test_seq  : (18684, 10, 51)

# %% [markdown]
# ### One Hot Encoding using to_categorical

# %%
# Keras softmax needs (n, 3)
y_train_cat = to_categorical(y_train_seq, num_classes=N_CLASSES)
y_val_cat   = to_categorical(y_val_seq,   num_classes=N_CLASSES)
y_test_cat  = to_categorical(y_test_seq,  num_classes=N_CLASSES)

print("\nONE-HOT SHAPES")
print("-" * 30)
print(f"y_train_cat : {y_train_cat.shape}")
print(f"y_val_cat   : {y_val_cat.shape}")
print(f"y_test_cat  : {y_test_cat.shape}")
# Out:
# ONE-HOT SHAPES
# ------------------------------
# y_train_cat : (112104, 3)
# y_val_cat   : (18684, 3)
# y_test_cat  : (18684, 3)

# %% [markdown]
# ### Building MLP (Multi layer Perceptron) -> Base Model

# %%
def build_mlp(input_shape,n_classes, learning_rate):
    model = Sequential([
        Input(shape = input_shape),
        Flatten(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.3),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.2),
        Dense(n_classes, activation = 'softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate, clipnorm=1.0),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

mlp_model = build_mlp(
    input_shape=(WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes = N_CLASSES,
    learning_rate=0.0001
)

mlp_model.summary()
# Out:
# 2026-06-04 21:45:41.169486: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 510)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       130,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 173,955 (679.51 KB)
#  Trainable params: 173,059 (676.01 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ### Build LSTM and CNN models

# %%
def build_lstm(input_shape, n_classes, learning_rate):
    model = Sequential([
        Input(shape=input_shape),
        GaussianNoise(0.005),

        LSTM(128,
             return_sequences=True,
             kernel_regularizer=l2(0.0005),
             recurrent_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        LSTM(64,
             return_sequences=False,
             kernel_regularizer=l2(0.0005),
             recurrent_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(n_classes, activation='softmax')
    ])

    model.compile(
        optimizer=Adam(learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

lstm_model = build_lstm(
    input_shape=(WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes=N_CLASSES,
    learning_rate = LEARNING_RATE
)

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gaussian_noise (GaussianNoise)  │ (None, 10, 51)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 10, 128)        │        92,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 10, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 10, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 144,515 (564.51 KB)
#  Trainable params: 144,131 (563.01 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
def build_cnn(input_shape, n_classes, learning_rate):

    model = Sequential([
        Conv1D(filters=64, kernel_size=3,
               activation="relu",
               kernel_regularizer=l2(0.0005),
               input_shape=input_shape),

        BatchNormalization(),   # to reduce internal covariance shift
        MaxPooling1D(pool_size=2),
        Dropout(0.3),

        Conv1D(filters= 128, kernel_size=3,
               activation="relu",
               kernel_regularizer=l2(0.0005)),
        BatchNormalization(),
        Dropout(0.3),

        Flatten(),   # flattening to 1D vector
        Dense(64, activation="relu"),
        Dropout(0.2),
        Dense(n_classes, activation="softmax")
    ])

    model.compile(
        optimizer=Adam(learning_rate, clipnorm=1.0),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

cnn_model = build_cnn(
    input_shape = (WINDOW_SIZE, X_train_seq.shape[2]),
    n_classes = N_CLASSES,
    learning_rate = LEARNING_RATE
)

cnn_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 8, 64)          │         9,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 64)          │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 2, 128)         │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 2, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,971 (203.01 KB)
#  Trainable params: 51,587 (201.51 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# ### Model Callbacks

# %%
def get_callbacks(model_name):
    return[
        EarlyStopping(
            monitor = "val_loss",
            patience = 15,
            restore_best_weights = True,
            min_delta = 0.001,
        ),
        ModelCheckpoint(
            filepath= artifacts_path/ f"{model_name}_best_live_model.keras",
            monitor = "val_loss",
            save_best_only = True,
            mode = "min",
            verbose = 1
        )
    ]

# %% [markdown]
# ### Training MLP

# %%
start_time = time.time()
print(start_time)

mlp_history = mlp_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("mlp"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(mlp_history.history['loss'])}")
# Out:
# 1780598744.247588
# Epoch 1/100
# 2026-06-04 21:45:45.108764: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8324 - loss: 0.4401
# Epoch 1: val_loss improved from None to 0.04102, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 1: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 27s 20ms/step - accuracy: 0.9400 - loss: 0.1825 - val_accuracy: 0.9943 - val_loss: 0.0410
# Epoch 2/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9940 - loss: 0.0280
# Epoch 2: val_loss improved from 0.04102 to 0.01658, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 2: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9945 - loss: 0.0248 - val_accuracy: 0.9964 - val_loss: 0.0166
# Epoch 3/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9957 - loss: 0.0169
# Epoch 3: val_loss improved from 0.01658 to 0.01367, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 3: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.9956 - loss: 0.0160 - val_accuracy: 0.9953 - val_loss: 0.0137
# Epoch 4/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9956 - loss: 0.0145
# Epoch 4: val_loss improved from 0.01367 to 0.00897, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 4: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.9958 - loss: 0.0131 - val_accuracy: 0.9963 - val_loss: 0.0090
# Epoch 5/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9960 - loss: 0.0109
# Epoch 5: val_loss improved from 0.00897 to 0.00714, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 5: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9959 - loss: 0.0109 - val_accuracy: 0.9967 - val_loss: 0.0071
# Epoch 6/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9964 - loss: 0.0095
# Epoch 6: val_loss did not improve from 0.00714
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9963 - loss: 0.0096 - val_accuracy: 0.9965 - val_loss: 0.0074
# Epoch 7/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9967 - loss: 0.0085
# Epoch 7: val_loss did not improve from 0.00714
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9966 - loss: 0.0083 - val_accuracy: 0.9967 - val_loss: 0.0084
# Epoch 8/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9966 - loss: 0.0088
# Epoch 8: val_loss improved from 0.00714 to 0.00624, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 8: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9968 - loss: 0.0082 - val_accuracy: 0.9974 - val_loss: 0.0062
# Epoch 9/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9970 - loss: 0.0071
# Epoch 9: val_loss improved from 0.00624 to 0.00513, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 9: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.9970 - loss: 0.0070 - val_accuracy: 0.9970 - val_loss: 0.0051
# Epoch 10/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9974 - loss: 0.0065
# Epoch 10: val_loss improved from 0.00513 to 0.00479, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 10: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9974 - loss: 0.0064 - val_accuracy: 0.9969 - val_loss: 0.0048
# Epoch 11/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9975 - loss: 0.0058
# Epoch 11: val_loss improved from 0.00479 to 0.00474, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 11: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9974 - loss: 0.0058 - val_accuracy: 0.9979 - val_loss: 0.0047
# Epoch 12/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9976 - loss: 0.0052
# Epoch 12: val_loss improved from 0.00474 to 0.00337, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 12: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9976 - loss: 0.0056 - val_accuracy: 0.9987 - val_loss: 0.0034
# Epoch 13/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9980 - loss: 0.0046
# Epoch 13: val_loss did not improve from 0.00337
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9977 - loss: 0.0052 - val_accuracy: 0.9985 - val_loss: 0.0038
# Epoch 14/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9980 - loss: 0.0042
# Epoch 14: val_loss improved from 0.00337 to 0.00309, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 14: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9979 - loss: 0.0043 - val_accuracy: 0.9987 - val_loss: 0.0031
# Epoch 15/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9981 - loss: 0.0046
# Epoch 15: val_loss improved from 0.00309 to 0.00219, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 15: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - accuracy: 0.9981 - loss: 0.0046 - val_accuracy: 0.9988 - val_loss: 0.0022
# Epoch 16/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9983 - loss: 0.0040
# Epoch 16: val_loss did not improve from 0.00219
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9983 - loss: 0.0040 - val_accuracy: 0.9988 - val_loss: 0.0023
# Epoch 17/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9985 - loss: 0.0034
# Epoch 17: val_loss improved from 0.00219 to 0.00200, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 17: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9985 - loss: 0.0036 - val_accuracy: 0.9993 - val_loss: 0.0020
# Epoch 18/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9982 - loss: 0.0039
# Epoch 18: val_loss improved from 0.00200 to 0.00168, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 18: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9982 - loss: 0.0040 - val_accuracy: 0.9991 - val_loss: 0.0017
# Epoch 19/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9983 - loss: 0.0039
# Epoch 19: val_loss did not improve from 0.00168
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9983 - loss: 0.0037 - val_accuracy: 0.9990 - val_loss: 0.0023
# Epoch 20/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9984 - loss: 0.0034
# Epoch 20: val_loss improved from 0.00168 to 0.00150, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 20: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9984 - loss: 0.0035 - val_accuracy: 0.9994 - val_loss: 0.0015
# Epoch 21/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9984 - loss: 0.0036
# Epoch 21: val_loss did not improve from 0.00150
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9983 - loss: 0.0036 - val_accuracy: 0.9987 - val_loss: 0.0023
# Epoch 22/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9988 - loss: 0.0032
# Epoch 22: val_loss did not improve from 0.00150
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9986 - loss: 0.0033 - val_accuracy: 0.9993 - val_loss: 0.0018
# Epoch 23/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9989 - loss: 0.0029
# Epoch 23: val_loss improved from 0.00150 to 0.00148, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 23: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - accuracy: 0.9988 - loss: 0.0029 - val_accuracy: 0.9995 - val_loss: 0.0015
# Epoch 24/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9988 - loss: 0.0028
# Epoch 24: val_loss improved from 0.00148 to 0.00137, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
#
# Epoch 24: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/mlp_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9988 - loss: 0.0029 - val_accuracy: 0.9994 - val_loss: 0.0014
# Epoch 25/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9989 - loss: 0.0033
# Epoch 25: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 15s 17ms/step - accuracy: 0.9988 - loss: 0.0033 - val_accuracy: 0.9992 - val_loss: 0.0023
# Epoch 26/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 26: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.9988 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0020
# Epoch 27/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9987 - loss: 0.0028
# Epoch 27: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 20s 23ms/step - accuracy: 0.9986 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0022
# Epoch 28/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9989 - loss: 0.0028
# Epoch 28: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.9989 - loss: 0.0027 - val_accuracy: 0.9991 - val_loss: 0.0018
# Epoch 29/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9989 - loss: 0.0030
# Epoch 29: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9989 - loss: 0.0028 - val_accuracy: 0.9992 - val_loss: 0.0031
# Epoch 30/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9992 - loss: 0.0020
# Epoch 30: val_loss did not improve from 0.00137
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 16s 18ms/step - accuracy: 0.9993 - loss: 0.0020 - val_accuracy: 0.9991 - val_loss: 0.0031
#
# Training time : 496.5s  (8.3 mins)
# Stopped at epoch: 30

# %% [markdown]
# ### Training LSTM

# %%
start_time = time.time()
print(start_time)

lstm_history = lstm_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("lstm"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(lstm_history.history['loss'])}")
# Out:
# 1780599241.1899078
# Epoch 1/100
# 2026-06-04 21:54:02.423900: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9706 - loss: 0.2194
# Epoch 1: val_loss improved from None to 0.04146, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 1: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 91s 88ms/step - accuracy: 0.9892 - loss: 0.1239 - val_accuracy: 0.9997 - val_loss: 0.0415
# Epoch 2/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9983 - loss: 0.0391
# Epoch 2: val_loss improved from 0.04146 to 0.01866, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 2: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.9986 - loss: 0.0334 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 3/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9996 - loss: 0.0181
# Epoch 3: val_loss improved from 0.01866 to 0.01573, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 3: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 74s 84ms/step - accuracy: 0.9990 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0157
# Epoch 4/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9989 - loss: 0.0175
# Epoch 4: val_loss improved from 0.01573 to 0.00866, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 4: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 81s 92ms/step - accuracy: 0.9994 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 5/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9987 - loss: 0.0129
# Epoch 5: val_loss did not improve from 0.00866
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 75s 85ms/step - accuracy: 0.9967 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 6/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9991 - loss: 0.0152
# Epoch 6: val_loss did not improve from 0.00866
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 74s 84ms/step - accuracy: 0.9984 - loss: 0.0168 - val_accuracy: 0.9988 - val_loss: 0.0212
# Epoch 7/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9990 - loss: 0.0163
# Epoch 7: val_loss did not improve from 0.00866
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 74s 84ms/step - accuracy: 0.9984 - loss: 0.0186 - val_accuracy: 0.9993 - val_loss: 0.0146
# Epoch 8/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9993 - loss: 0.0140
# Epoch 8: val_loss did not improve from 0.00866
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9987 - loss: 0.0159 - val_accuracy: 0.9890 - val_loss: 0.0381
# Epoch 9/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9966 - loss: 0.0202
# Epoch 9: val_loss improved from 0.00866 to 0.00650, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 9: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 79s 90ms/step - accuracy: 0.9985 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 10/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9981 - loss: 0.0164
# Epoch 10: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 72s 83ms/step - accuracy: 0.9983 - loss: 0.0176 - val_accuracy: 0.9981 - val_loss: 0.0156
# Epoch 11/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9994 - loss: 0.0111
# Epoch 11: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 84ms/step - accuracy: 0.9994 - loss: 0.0121 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 12/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9991 - loss: 0.0126
# Epoch 12: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 72s 82ms/step - accuracy: 0.9978 - loss: 0.0162 - val_accuracy: 0.9975 - val_loss: 0.0233
# Epoch 13/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9968 - loss: 0.0223
# Epoch 13: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 72s 83ms/step - accuracy: 0.9983 - loss: 0.0165 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 14/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9997 - loss: 0.0084
# Epoch 14: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9994 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 15/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9995 - loss: 0.0090
# Epoch 15: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9986 - loss: 0.0159 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 16/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9993 - loss: 0.0138
# Epoch 16: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9991 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 17/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.9997 - loss: 0.0075
# Epoch 17: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 72s 82ms/step - accuracy: 0.9994 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 18/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9987 - loss: 0.0093
# Epoch 18: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 65s 74ms/step - accuracy: 0.9964 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 19/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9998 - loss: 0.0089
# Epoch 19: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 60s 68ms/step - accuracy: 0.9997 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 20/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9998 - loss: 0.0062
# Epoch 20: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 59s 67ms/step - accuracy: 0.9981 - loss: 0.0114 - val_accuracy: 0.9810 - val_loss: 0.0327
# Epoch 21/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9913 - loss: 0.0301
# Epoch 21: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 60s 69ms/step - accuracy: 0.9945 - loss: 0.0225 - val_accuracy: 0.9996 - val_loss: 0.0097
# Epoch 22/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9995 - loss: 0.0090
# Epoch 22: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 59s 68ms/step - accuracy: 0.9993 - loss: 0.0093 - val_accuracy: 0.9997 - val_loss: 0.0093
# Epoch 23/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9998 - loss: 0.0075
# Epoch 23: val_loss did not improve from 0.00650
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 74s 85ms/step - accuracy: 0.9995 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 24/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9986 - loss: 0.0150
# Epoch 24: val_loss improved from 0.00650 to 0.00564, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
#
# Epoch 24: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/lstm_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 73s 83ms/step - accuracy: 0.9992 - loss: 0.0103 - val_accuracy: 1.0000 - val_loss: 0.0056
#
# Training time : 1726.8s  (28.8 mins)
# Stopped at epoch: 24

# %% [markdown]
# ### Training CNN

# %%
start_time = time.time()
print(start_time)

cnn_history = cnn_model.fit(
    X_train_seq, y_train_cat,
    validation_data=(X_val_seq, y_val_cat),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=get_callbacks("cnn"),
    verbose=1
)

end_time = time.time()
print(f"\nTraining time : {(end_time - start_time):.1f}s  "
      f"({(end_time - start_time) / 60:.1f} mins)")
print(f"Stopped at epoch: {len(cnn_history.history['loss'])}")
# Out:
# 1780600968.3037858
# Epoch 1/100
# 2026-06-04 22:22:49.544798: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 228692160 exceeds 10% of free system memory.
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9451 - loss: 0.1984
# Epoch 1: val_loss improved from None to 0.03530, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 1: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - accuracy: 0.9842 - loss: 0.0944 - val_accuracy: 0.9986 - val_loss: 0.0353
# Epoch 2/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9979 - loss: 0.0336
# Epoch 2: val_loss improved from 0.03530 to 0.01972, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 2: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9978 - loss: 0.0295 - val_accuracy: 0.9988 - val_loss: 0.0197
# Epoch 3/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9973 - loss: 0.0252
# Epoch 3: val_loss improved from 0.01972 to 0.01639, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 3: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9975 - loss: 0.0229 - val_accuracy: 0.9983 - val_loss: 0.0164
# Epoch 4/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9973 - loss: 0.0196
# Epoch 4: val_loss improved from 0.01639 to 0.01042, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 4: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9972 - loss: 0.0199 - val_accuracy: 0.9998 - val_loss: 0.0104
# Epoch 5/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9988 - loss: 0.0137
# Epoch 5: val_loss did not improve from 0.01042
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9983 - loss: 0.0152 - val_accuracy: 0.9989 - val_loss: 0.0130
# Epoch 6/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0158
# Epoch 6: val_loss improved from 0.01042 to 0.00714, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 6: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9984 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 7/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0134
# Epoch 7: val_loss did not improve from 0.00714
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9981 - loss: 0.0131 - val_accuracy: 0.9995 - val_loss: 0.0083
# Epoch 8/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9987 - loss: 0.0130
# Epoch 8: val_loss improved from 0.00714 to 0.00617, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 8: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9986 - loss: 0.0134 - val_accuracy: 0.9998 - val_loss: 0.0062
# Epoch 9/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9988 - loss: 0.0094
# Epoch 9: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9984 - loss: 0.0112 - val_accuracy: 0.9990 - val_loss: 0.0094
# Epoch 10/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9990 - loss: 0.0104
# Epoch 10: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9987 - loss: 0.0115 - val_accuracy: 0.9927 - val_loss: 0.0499
# Epoch 11/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9984 - loss: 0.0123
# Epoch 11: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9985 - loss: 0.0115 - val_accuracy: 0.9997 - val_loss: 0.0069
# Epoch 12/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9990 - loss: 0.0094
# Epoch 12: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9986 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 13/100
# 873/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9987 - loss: 0.0117
# Epoch 13: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9985 - loss: 0.0125 - val_accuracy: 0.9984 - val_loss: 0.0177
# Epoch 14/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9986 - loss: 0.0119
# Epoch 14: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9986 - loss: 0.0114 - val_accuracy: 0.9987 - val_loss: 0.0076
# Epoch 15/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9984 - loss: 0.0120
# Epoch 15: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9985 - loss: 0.0118 - val_accuracy: 0.9968 - val_loss: 0.0117
# Epoch 16/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9986 - loss: 0.0114
# Epoch 16: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9986 - loss: 0.0110 - val_accuracy: 0.9983 - val_loss: 0.0122
# Epoch 17/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9989 - loss: 0.0102
# Epoch 17: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9989 - loss: 0.0099 - val_accuracy: 0.9996 - val_loss: 0.0073
# Epoch 18/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9989 - loss: 0.0096
# Epoch 18: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9984 - loss: 0.0117 - val_accuracy: 0.9995 - val_loss: 0.0077
# Epoch 19/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9989 - loss: 0.0103
# Epoch 19: val_loss did not improve from 0.00617
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9986 - loss: 0.0116 - val_accuracy: 0.9992 - val_loss: 0.0082
# Epoch 20/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0119
# Epoch 20: val_loss improved from 0.00617 to 0.00600, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 20: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9985 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 21/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9988 - loss: 0.0097
# Epoch 21: val_loss improved from 0.00600 to 0.00597, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 21: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9985 - loss: 0.0108 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 22/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9988 - loss: 0.0096
# Epoch 22: val_loss did not improve from 0.00597
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9985 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 23/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9992 - loss: 0.0094
# Epoch 23: val_loss improved from 0.00597 to 0.00534, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 23: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9989 - loss: 0.0100 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 24/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9989 - loss: 0.0093
# Epoch 24: val_loss did not improve from 0.00534
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 20ms/step - accuracy: 0.9988 - loss: 0.0099 - val_accuracy: 0.9999 - val_loss: 0.0056
# Epoch 25/100
# 875/876 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9982 - loss: 0.0113
# Epoch 25: val_loss did not improve from 0.00534
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9982 - loss: 0.0119 - val_accuracy: 0.9987 - val_loss: 0.0100
# Epoch 26/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9989 - loss: 0.0095
# Epoch 26: val_loss improved from 0.00534 to 0.00478, saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
#
# Epoch 26: finished saving model to /home/darlenewendie/IdeaProjects/ai-pipeline-leak-detection/ml_service/artifacts/cnn_best_live_model.keras
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 93s 106ms/step - accuracy: 0.9988 - loss: 0.0096 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 27/100
# 869/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9987 - loss: 0.0100
# Epoch 27: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9984 - loss: 0.0112 - val_accuracy: 0.9999 - val_loss: 0.0056
# Epoch 28/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0092
# Epoch 28: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9989 - loss: 0.0092 - val_accuracy: 0.9987 - val_loss: 0.0283
# Epoch 29/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9986 - loss: 0.0099
# Epoch 29: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9987 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 30/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0092
# Epoch 30: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9990 - loss: 0.0086 - val_accuracy: 0.9991 - val_loss: 0.0070
# Epoch 31/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9977 - loss: 0.0132
# Epoch 31: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9984 - loss: 0.0116 - val_accuracy: 0.9997 - val_loss: 0.0056
# Epoch 32/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9985 - loss: 0.0091
# Epoch 32: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9986 - loss: 0.0096 - val_accuracy: 0.9996 - val_loss: 0.0063
# Epoch 33/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0095
# Epoch 33: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9986 - loss: 0.0101 - val_accuracy: 0.9995 - val_loss: 0.0072
# Epoch 34/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0097
# Epoch 34: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0102 - val_accuracy: 0.9998 - val_loss: 0.0056
# Epoch 35/100
# 874/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9992 - loss: 0.0078
# Epoch 35: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9989 - loss: 0.0090 - val_accuracy: 0.9980 - val_loss: 0.0096
# Epoch 36/100
# 871/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0091
# Epoch 36: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0096 - val_accuracy: 0.9996 - val_loss: 0.0076
# Epoch 37/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9989 - loss: 0.0092
# Epoch 37: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0104 - val_accuracy: 0.9995 - val_loss: 0.0079
# Epoch 38/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0096
# Epoch 38: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9989 - loss: 0.0094 - val_accuracy: 0.9981 - val_loss: 0.0092
# Epoch 39/100
# 870/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0081
# Epoch 39: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0091 - val_accuracy: 0.9989 - val_loss: 0.0084
# Epoch 40/100
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9986 - loss: 0.0107
# Epoch 40: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9987 - loss: 0.0102 - val_accuracy: 0.9978 - val_loss: 0.0277
# Epoch 41/100
# 868/876 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9988 - loss: 0.0101
# Epoch 41: val_loss did not improve from 0.00478
# 876/876 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9988 - loss: 0.0100 - val_accuracy: 0.9982 - val_loss: 0.0080
#
# Training time : 639.3s  (10.7 mins)
# Stopped at epoch: 41

# %% [markdown]
# ### Plot Training accuracy

# %%
ASSETS_PATH.mkdir(parents=True, exist_ok=True)

def plot_history(history, model_name):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    fig.suptitle(f"{model_name} Training History live data", fontsize=14, fontweight="bold")

    epochs_range = range(1, len(history.history["loss"]) + 1)

    # best epoch indices
    best_epoch_idx     = int(np.argmin(history.history["val_loss"]))
    best_epoch         = best_epoch_idx + 1
    best_val_loss      = history.history["val_loss"][best_epoch_idx]

    best_val_acc_idx   = int(np.argmax(history.history["val_accuracy"]))
    best_val_acc_epoch = best_val_acc_idx + 1
    best_val_acc       = history.history["val_accuracy"][best_val_acc_idx]

    # gap at best epoch — not final epoch
    gap = (history.history['accuracy'][best_epoch_idx] -
           history.history['val_accuracy'][best_epoch_idx])

    # ── Subplot 1: Loss
    ax1.plot(epochs_range, history.history["loss"],
             label="Train Loss", color="#60a5fa", linewidth=2)
    ax1.plot(epochs_range, history.history["val_loss"],
             label="Val Loss",   color="#fb923c", linewidth=2)

    ax1.axvline(best_epoch, color="#4ade80", linestyle="--", alpha=0.7,
                label=f"Best epoch ({best_epoch})")
    ax1.scatter([best_epoch], [best_val_loss], color="#4ade80", s=80, zorder=5)

    ax1.set_title("Training vs Validation Loss Live data")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.legend()
    ax1.grid(alpha=0.3)

    #  Subplot 2: Accuracy
    ax2.plot(epochs_range, history.history["accuracy"],
             label="Train Accuracy", color="#4ade80", linewidth=2)
    ax2.plot(epochs_range, history.history["val_accuracy"],
             label="Val Accuracy",   color="#f472b6", linewidth=2)

    ax2.axvline(best_val_acc_epoch, color="#fbbf24", linestyle="--", alpha=0.7,
                label=f"Best val_acc epoch ({best_val_acc_epoch})")
    ax2.scatter([best_val_acc_epoch], [best_val_acc],
                color="#fbbf24", s=80, zorder=5)

    ax2.set_title("Training vs Validation Accuracy")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Accuracy")
    ax2.set_ylim([0, 1.05])
    ax2.legend()
    ax2.grid(alpha=0.3)

    plt.tight_layout()
    save_path = ASSETS_PATH / f"{model_name.lower()}_training_history.png"
    plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()

    # Diagnosis at best epoch
    print(f"\n{model_name} TRAINING DIAGNOSIS")
    print("-" * 40)
    print(f"Total epochs run      : {len(history.history['loss'])}")
    print(f"Best val_loss         : {best_val_loss:.4f}  (epoch {best_epoch})")
    print(f"Best val_accuracy     : {best_val_acc:.4f}  (epoch {best_val_acc_epoch})")
    print(f"Train accuracy @ best : {history.history['accuracy'][best_epoch_idx]:.4f}")
    print(f"Val accuracy   @ best : {history.history['val_accuracy'][best_epoch_idx]:.4f}")
    print(f"Train/Val gap         : {gap:.4f}  {'OVERFIT' if gap > 0.05 else 'OK'}")


# ── Call for all three models
plot_history(lstm_history, "LSTM")
plot_history(cnn_history,  "CNN")
plot_history(mlp_history,  "MLP")
# Out:
# LSTM TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 24
# Best val_loss         : 0.0056  (epoch 24)
# Best val_accuracy     : 1.0000  (epoch 2)
# Train accuracy @ best : 0.9992
# Val accuracy   @ best : 1.0000
# Train/Val gap         : -0.0008  OK
# CNN TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 41
# Best val_loss         : 0.0048  (epoch 26)
# Best val_accuracy     : 1.0000  (epoch 6)
# Train accuracy @ best : 0.9988
# Val accuracy   @ best : 1.0000
# Train/Val gap         : -0.0012  OK
# MLP TRAINING DIAGNOSIS
# ----------------------------------------
# Total epochs run      : 30
# Best val_loss         : 0.0014  (epoch 24)
# Best val_accuracy     : 0.9995  (epoch 23)
# Train accuracy @ best : 0.9988
# Val accuracy   @ best : 0.9994
# Train/Val gap         : -0.0006  OK

# %% [markdown]
# ### Evaluate on Validation set

# %%
def evaluate_model(model, model_name, X_val_seq, y_val_cat):
    """
    - Classification report
    - Confusion matrix (counts + percentages)
    - Leak recall extraction
    - Saves confusion matrix to assets folder
    """
    CLASS_NAMES = ["Normal", "Leak", "Blockage"]

    # Predict
    y_pred_prob = model.predict(X_val_seq, verbose=0)
    y_pred      = np.argmax(y_pred_prob, axis=1)
    y_true      = np.argmax(y_val_cat,   axis=1)

    # Classification Report
    print("=" * 50)
    print(f"{model_name} — LIVE DATA VALIDATION SET RESULTS")
    print("=" * 50)
    print(classification_report(
        y_true, y_pred,
        target_names=CLASS_NAMES,
        digits=4
    ))

    # Leak Recall
    leak_recall = recall_score(y_true, y_pred, labels=[1], average=None)[0]

    # Confusion Matrix
    cm     = confusion_matrix(y_true, y_pred)
    cm_pct = cm.astype(float) / cm.sum(axis=1, keepdims=True) * 100

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                ax=axes[0], linewidths=0.5)
    axes[0].set_title("Confusion Matrix — Counts")
    axes[0].set_ylabel("True Label")
    axes[0].set_xlabel("Predicted Label")

    sns.heatmap(cm_pct, annot=True, fmt=".1f", cmap="RdYlGn",
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES,
                ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
    axes[1].set_title("Confusion Matrix — % per True Class")
    axes[1].set_ylabel("True Label")
    axes[1].set_xlabel("Predicted Label")

    plt.suptitle(f"{model_name} — Validation Set Confusion Matrix",
                 fontweight="bold")
    plt.tight_layout()

    save_path = ASSETS_PATH / f"{model_name.lower()}_val_confusion.png"
    plt.savefig(save_path, dpi=150, bbox_inches="tight")
    plt.show()

    return leak_recall


# Run for all three models
leak_recall_lstm = evaluate_model(lstm_model, "LSTM", X_val_seq, y_val_cat)
leak_recall_cnn  = evaluate_model(cnn_model,  "CNN",  X_val_seq, y_val_cat)
leak_recall_mlp  = evaluate_model(mlp_model,  "MLP",  X_val_seq, y_val_cat)
# Out:
# ==================================================
# LSTM — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    1.0000    1.0000      6228
#         Leak     1.0000    1.0000    1.0000      6228
#     Blockage     1.0000    1.0000    1.0000      6228
#
#     accuracy                         1.0000     18684
#    macro avg     1.0000    1.0000    1.0000     18684
# weighted avg     1.0000    1.0000    1.0000     18684
# ==================================================
# CNN — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    1.0000    1.0000      6228
#         Leak     1.0000    1.0000    1.0000      6228
#     Blockage     1.0000    1.0000    1.0000      6228
#
#     accuracy                         1.0000     18684
#    macro avg     1.0000    1.0000    1.0000     18684
# weighted avg     1.0000    1.0000    1.0000     18684
# ==================================================
# MLP — LIVE DATA VALIDATION SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     0.9981    0.9986    0.9983      6228
#         Leak     0.9982    0.9981    0.9982      6228
#     Blockage     1.0000    0.9997    0.9998      6228
#
#     accuracy                         0.9988     18684
#    macro avg     0.9988    0.9988    0.9988     18684
# weighted avg     0.9988    0.9988    0.9988     18684

# %%
# Load best checkpoint
best_model = load_model(artifacts_path/ "lstm_best_live_model.keras")
print(" Loaded best checkpoint: lstm_best.keras")

# Predict on test set
y_pred_prob_test = best_model.predict(X_test_seq, verbose=0)
y_pred_test      = np.argmax(y_pred_prob_test, axis=1)
y_true_test      = np.argmax(y_test_cat, axis=1)

# Final Classification Report
print("\n" + "=" * 50)
print("LSTM — FINAL TEST SET RESULTS")
print("=" * 50)
print(classification_report(
    y_true_test, y_pred_test,
    target_names=["Normal", "Leak", "Blockage"],
    digits=4
))

# Final Confusion Matrix
cm_test     = confusion_matrix(y_true_test, y_pred_test)
cm_test_pct = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[0], linewidths=0.5)
axes[0].set_title("Test Confusion Matrix — Counts")
axes[0].set_ylabel("True Label")
axes[0].set_xlabel("Predicted Label")

sns.heatmap(cm_test_pct, annot=True, fmt=".1f", cmap="RdYlGn",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
axes[1].set_title("Test Confusion Matrix — % per True Class")
axes[1].set_ylabel("True Label")
axes[1].set_xlabel("Predicted Label")

plt.suptitle("LSTM — Final Test Set Evaluation", fontweight="bold")
plt.tight_layout()
save_path = ASSETS_PATH /"lstm_test_confusion.png"
plt.savefig(save_path, dpi=150, bbox_inches="tight")
plt.show()
# Out:
#  Loaded best checkpoint: lstm_best.keras
#
# ==================================================
# LSTM — FINAL TEST SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.9994    0.9997      6228
#         Leak     1.0000    1.0000    1.0000      6228
#     Blockage     0.9994    1.0000    0.9997      6228
#
#     accuracy                         0.9998     18684
#    macro avg     0.9998    0.9998    0.9998     18684
# weighted avg     0.9998    0.9998    0.9998     18684

# %%
# Load best checkpoint
best_model = load_model(artifacts_path/ "cnn_best_live_model.keras")
print(" Loaded best checkpoint: cnn_best.keras")

# Predict on test set
y_pred_prob_test = best_model.predict(X_test_seq, verbose=0)
y_pred_test      = np.argmax(y_pred_prob_test, axis=1)
y_true_test      = np.argmax(y_test_cat, axis=1)

# Final Classification Report
print("\n" + "=" * 50)
print("CNN — FINAL TEST SET RESULTS")
print("=" * 50)
print(classification_report(
    y_true_test, y_pred_test,
    target_names=["Normal", "Leak", "Blockage"],
    digits=4
))

# Final Confusion Matrix
cm_test     = confusion_matrix(y_true_test, y_pred_test)
cm_test_pct = cm_test.astype(float) / cm_test.sum(axis=1, keepdims=True) * 100

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[0], linewidths=0.5)
axes[0].set_title("Test Confusion Matrix — Counts")
axes[0].set_ylabel("True Label")
axes[0].set_xlabel("Predicted Label")

sns.heatmap(cm_test_pct, annot=True, fmt=".1f", cmap="RdYlGn",
            xticklabels=["Normal", "Leak", "Blockage"],
            yticklabels=["Normal", "Leak", "Blockage"],
            ax=axes[1], linewidths=0.5, vmin=0, vmax=100)
axes[1].set_title("Test Confusion Matrix — % per True Class")
axes[1].set_ylabel("True Label")
axes[1].set_xlabel("Predicted Label")

plt.suptitle("CNN — Final Test Set Evaluation", fontweight="bold")
plt.tight_layout()
save_path = ASSETS_PATH /"cnn_test_confusion.png"
plt.savefig(save_path, dpi=150, bbox_inches="tight")
plt.show()
# Out:
#  Loaded best checkpoint: cnn_best.keras
#
# ==================================================
# CNN — FINAL TEST SET RESULTS
# ==================================================
#               precision    recall  f1-score   support
#
#       Normal     1.0000    0.9987    0.9994      6228
#         Leak     0.9987    1.0000    0.9994      6228
#     Blockage     1.0000    1.0000    1.0000      6228
#
#     accuracy                         0.9996     18684
#    macro avg     0.9996    0.9996    0.9996     18684
# weighted avg     0.9996    0.9996    0.9996     18684
